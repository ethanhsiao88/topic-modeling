# %%
# %pip install torch
# %pip install transformers
# %pip install flair
# %pip install vaderSentiment
# %pip install textblob
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
import flair
flair_sentiment = flair.models.TextClassifier.load('en-sentiment')
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">2021-07-20 19:42:36,392 https://nlp.informatik.hu-berlin.de/resources/models/sentiment-curated-distilbert/sentiment-en-mix-distillbert_4.pt not found in cache, downloading to /tmp/tmp22ebi5f1
# 100%|██████████| 265512723/265512723 [00:25&lt;00:00, 10392481.11B/s]
# 2021-07-20 19:43:02,268 copying /tmp/tmp22ebi5f1 to cache at /root/.flair/models/sentiment-en-mix-distillbert_4.pt
# 2021-07-20 19:43:02,591 removing temp file /tmp/tmp22ebi5f1
# 2021-07-20 19:43:02,622 loading file /root/.flair/models/sentiment-en-mix-distillbert_4.pt
# Downloading: 100%|██████████| 28.0/28.0 [00:00&lt;00:00, 50.8kB/s]
# Downloading: 100%|██████████| 232k/232k [00:00&lt;00:00, 59.7MB/s]
# Downloading: 100%|██████████| 466k/466k [00:00&lt;00:00, 65.4MB/s]
# </div>

# %%
import torch
from transformers.file_utils import is_tf_available, is_torch_available, is_torch_tpu_available
from transformers import BertTokenizerFast, BertForSequenceClassification
from transformers import Trainer, TrainingArguments
import numpy as np
import random
from sklearn.model_selection import train_test_split
import numpy as np
from pyspark.sql.functions import col
import pandas as pd
import calendar
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
def set_seed(seed: int):
    """
    Helper function for reproducible behavior to set the seed in ``random``, ``numpy``, ``torch`` and/or ``tf`` (if
    installed).

    Args:
        seed (:obj:`int`): The seed to set.
    """
    random.seed(seed)
    np.random.seed(seed)
    if is_torch_available():
        torch.manual_seed(seed)
        torch.cuda.manual_seed_all(seed)
        # ^^ safe to call this function even if cuda is not available
    if is_tf_available():
        import tensorflow as tf

        tf.random.set_seed(seed)

set_seed(1)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
# the model we gonna train, base uncased BERT (https://huggingface.co/models?filter=text-classification)
model_name = "bert-base-uncased"
max_length = 200 # max sequence length for each document/sentence sample
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
# load the tokenizer
tokenizer = BertTokenizerFast.from_pretrained(model_name, do_lower_case=True)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>

# %% [markdown]
# ###Read data

# %%
#Read data from widget

BASE_PATH = "a) Training Data Path"
dbutils.widgets.text(BASE_PATH, "s3://ipsy-databricks-mlp/research/ethan/all_detractors_gb_gbplus_gbx_feb_to_jun.csv")
base_path = dbutils.widgets.get(BASE_PATH)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
#df = read('s3://ipsy-databricks-mlp/research/ethan/first1500detractorsmonolabeled.csv', ',')
#df = read('s3://ipsy-databricks-mlp/research/ethan/alldetractorsmonolabeled.csv', ',')
#df = spark.read.csv('s3://ipsy-databricks-mlp/research/ethan/all_detractors_gb_gbplus_gbx_feb_to_jun.csv', header=True)

df = spark.read.csv(base_path, header=True)
print('num rows: ', df.count())

df.display()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">num rows:  10822
# </div>
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>
tr><tr><td>2021-03-26 11:56:00</td><td>2021-03-26 12:01:00</td><td>u-h93ltzheptvh48o</td><td>GB</td><td>3</td><td>C</td><td>6</td><td>Need a little more variety.</td></tr><tr><td>2021-03-26 11:20:00</td><td>2021-03-26 11:54:00</td><td>u-ha4jvgqqka9r2mv</td><td>GB</td><td>3</td><td>C</td><td>6</td><td>I feel like I get the same colors all the time. I like the products and do get a different color every once in a while, but wouldn't recommend ...

# %%
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>

# %% [markdown]
# ###Preprocessing

# %%
#rename columns
df = df.withColumnRenamed('How likely are you to recommend the Glam Bag to a friend?', 'nps')
df = df.withColumnRenamed('What is the most important reason for your recommendation answer?', 'comments')
df = df.withColumnRenamed('Start Date', 'start')
df = df.withColumnRenamed('End Date', 'end')
df = df.withColumnRenamed('Subscription', 'subscription')
df.display()
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>start</th><th>end</th><th>userId</th><th>subscription</th><th>topic_type</th><th>business_topic_type</th><th>nps</th><th>comments</th></tr></thead><tbody><tr><td>2021-03-26 15:05:00</td><td>2021-03-26 15:09:00</td><td>u-h050dssk4l1jjw7</td><td>GB</td><td>2</td><td>B</td><td>5</td><td>Unreliable shipping</td></tr><tr><td>2021-03-26 23:49:00</td><td>2021-03-26 23:55:00</td><td>u-h0512xdjmys21ik5</td><td>GB</td><td>1</td><td>A</td><td>4</td><td>I wouldn't always recommend because I feel like my bags have been SO hit or miss lately</td></tr><tr><td>2021-03-26 11:45:00</td><td>2021-03-26 11:51:00</td><td>u-h0516q8jpz5o1z9e</td><td>GB</td><td>3</td><td>C</td><td>6</td><td>It's a great concept but I do feel like it can get quiet repetitive.</td></tr><tr><td>2021-02-27 03:18:00</td><td>2021-02-27 03:22:00</td><td>u-h0519qrpokqm7nm</td><td>GB</td><td>5, 8, 9</td><td>E, F</td><td>5</td><td>"I've been with this company from the very beginning! I was there when people were begging to have a subscription! I felt lucky to get in first when Phawn started My GlamBag! I still have the very first GlamBag! But I don't know anymore‚Ä¶.Most of the products were full size but now I have to pay to ""upgrade"". I was only paying $10 a month</td></tr><tr><td>2021-02-26 11:19:00</td><td>2021-02-26 11:39:00</td><td>u-h051av04fqdpcvj</td><td>GB</td><td>3, 5</td><td>C, F</td><td>4</td><td>Most items are sample sized, and after a while it's just the same things over and over again. The best part for me is becoming the bag itself, not the items, and even the bag sometimes is a hit and miss.</td></tr><tr><td>2021-02-26 14:54:00</td><td>2021-02-26 14:57:00</td><td>u-h051m9he429a1sx2</td><td>GB</td><td>3</td><td>C</td><td>6</td><td>Love the bags, but the products can be repetitive</td></tr><tr><td>2021-02-26 11:11:00</td><td>2021-02-26 11:14:00</td><td>u-h051q6k26coy5fg</td><td>GB</td><td>2</td><td>B</td><td>3</td><td>The time to receive it in Canada</td></tr><tr><td>2021-02-26 11:13:00</td><td>2021-02-26 11:46:00</td><td>u-h051xhknju0i14jt</td><td>GB</td><td>3</td><td>C</td><td>6</td><td>seems too many duplicates</td></tr><tr><td>2021-03-26 11:45:00</td><td>2021-03-26 11:49:00</td><td>u-h0dxjpwaodmcxp</td><td>GB</td><td>2</td><td>B</td><td>6</td><td>i enjoyed it in the past and just reopened my account but it's been13 days and I still don't have my shipment</td></tr><tr><td>2021-02-26 11:33:00</td><td>2021-02-26 11:40:00</td><td>u-h1ammj222zqc2ch</td><td>GB</td><td>1</td><td>A</td><td>5</td><td>My preferred colors are not generally provided. I do give away quite a few products.</td></tr><tr><td>2021-02-26 11:07:00</td><td>2021-02-26 11:22:00</td><td>u-h5e6gdlfecfbadk</td><td>GB</td><td>5</td><td>F</td><td>5</td><td>Too many mini products. I live in Canada and I would prefer to pay extra for full-size products but those options aren't available to me</td></tr><tr><td>2021-02-26 16:36:00</td><td>2021-02-26 16:41:00</td><td>u-h7kycw0w7fqd17x</td><td>GB</td><td>3</td><td>C, D</td><td>5</td><td>It's good for the price but it's not always exciting because they repeat products or do too many of the same type in one bag</td></tr><tr><td>2021-02-26 13:50:00</td><td>2021-02-26 14:04:00</td><td>u-h7l9mjgk7dhu71f</td><td>GB</td><td>11</td><td>F</td><td>6</td><td>There can be some good products</td></tr><tr><td>2021-03-26 11:56:00</td><td>2021-03-26 12:01:00</td><td>u-h93ltzheptvh48o</td><td>GB</td><td>3</td><td>C</td><td>6</td><td>Need a little more variety.</td></tr><tr><td>2021-03-26 11:20:00</td><td>2021-03-26 11:54:00</td><td>u-ha4jvgqqka9r2mv</td><td>GB</td><td>3</td><td>C</td><td>6</td><td>I feel like I get the same colors all the time. I like the products and do get a different color every once in a while, but wouldn't recommend based on the lack of variety.</td></tr><tr><td>2021-02-26 17:41:00</td><td>2021-02-26 21:45:00</td><td>u-hbq5kjbu7hnb1xs ...

# %%
#Filter out null comments, make nps all ints
df = df.filter(df["comments"].isNotNull())
df = df.filter(df["topic_type"].isNotNull())
df = df.replace("10 = Extremely likely", '10', ['nps']).replace("0 = Not at all likely", '0', ['nps']) # added new
df = df.withColumn('nps', df.nps.cast('int'))
df.display()
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>start</th><th>end</th><th>userId</th><th>subscription</th><th>topic_type</th><th>business_topic_type</th><th>nps</th><th>comments</th></tr></thead><tbody><tr><td>2021-03-26 15:05:00</td><td>2021-03-26 15:09:00</td><td>u-h050dssk4l1jjw7</td><td>GB</td><td>2</td><td>B</td><td>5</td><td>Unreliable shipping</td></tr><tr><td>2021-03-26 23:49:00</td><td>2021-03-26 23:55:00</td><td>u-h0512xdjmys21ik5</td><td>GB</td><td>1</td><td>A</td><td>4</td><td>I wouldn't always recommend because I feel like my bags have been SO hit or miss lately</td></tr><tr><td>2021-03-26 11:45:00</td><td>2021-03-26 11:51:00</td><td>u-h0516q8jpz5o1z9e</td><td>GB</td><td>3</td><td>C</td><td>6</td><td>It's a great concept but I do feel like it can get quiet repetitive.</td></tr><tr><td>2021-02-27 03:18:00</td><td>2021-02-27 03:22:00</td><td>u-h0519qrpokqm7nm</td><td>GB</td><td>5, 8, 9</td><td>E, F</td><td>5</td><td>"I've been with this company from the very beginning! I was there when people were begging to have a subscription!
: </div>
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>start</th>
#       <th>end</th>
#       <th>topic_type</th>
#       <th>nps</th>
#       <th>comments</th>
#       <th>subscription</th>
#       <th>userId</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>2021-03-26 15:05:00</td>
#       <td>2021-03-26 15:09:00</td>
#       <td>2</td>
#       <td>5</td>
#       <td>Unreliable shipping</td>
#       <td>GB</td>
#       <td>u-h050dssk4l1jjw7</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>2021-03-26 23:49:00</td>
#       <td>2021-03-26 23:55:00</td>
#       <td>1</td>
#       <td>4</td>
#       <td>I wouldn't always recommend because I feel lik...</td>
#       <td>GB</td>
#       <td>u-h0512xdjmys21ik5</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>2021-03-26 11:45:00</td>
#       <td>2021-03-26 11:51:00</td>
#       <td>3</td>
#       <td>6</td>
#       <td>It's a great concept but I do feel like it can...</td>
#       <td>GB</td>
#       <td>u-h0516q8jpz5o1z9e</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>2021-02-27 03:18:00</td>
#       <td>2021-02-27 03:22:00</td>
#       <td>5, 8, 9</td>
#       <td>5</td>
#       <td>"I've been with this company from the very beg...</td>
#       <td>GB</td>
#       <td>u-h0519qrpokqm7nm</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>2021-02-26 11:19:00</td>
#       <td>2021-02-26 11:39:00</td>
#       <td>3, 5</td>
#       <td>4</td>
#       <td>Most items are sample sized, and after a while...</td>
#       <td>GB</td>
#       <td>u-h051av04fqdpcvj</td>
#     </tr>
#     <tr>
#       <th>...</th>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#     </tr>
#     <tr>
#       <th>10817</th>
#       <td>2021-05-27 15:04:00</td>
#       <td>2021-05-27 15:10:00</td>
#       <td>10</td>
#       <td>0</td>
#       <td>I don't like your products.</td>
#       <td>GBX</td>
#       <td>u-km448odifvrb6g4</td>
#     </tr>
#     <tr>
#       <th>10818</th>
#       <td>2021-05-27 15:04:00</td>
#       <td>2021-05-27 15:08:00</td>
#       <td>8</td>
#       <td>3</td>
#       <td>Too many bags, allow the option to go bagless!</td>
#       <td>GBX</td>
#       <td>u-kkpn5f2750jt15hf</td>
#     </tr>
#     <tr>
#       <th>10819</th>
#       <td>2021-05-27 15:03:00</td>
#       <td>2021-05-27 15:04:00</td>
#       <td>2</td>
#       <td>2</td>
#       <td>It has been over a month and I still haven't r...</td>
#       <td>GBX</td>
#       <td>u-kndy2lj1fc31nv5</td>
#     </tr>
#     <tr>
#       <th>10820</th>
#       <td>2021-05-27 15:03:00</td>
#       <td>2021-05-27 15:15:00</td>
#       <td>9</td>
#       <td>0</td>
#       <td>Because it wasn't worth it to me. Spending tha...</td>
#       <td>GBX</td>
#       <td>u-ist8xiki612uefx</td>
#     </tr>
#     <tr>
#       <th>10821</th>
#       <td>2021-05-27 15:03:00</td>
#       <td>2021-05-27 15:08:00</td>
#       <td>2</td>
#       <td>4</td>
#       <td>Only received one month so far</td>
#       <td>GBX</td>
#       <td>u-ko4adrzogvyccyf</td>
#     </tr>
#   </tbody>
# </table>
# <p>10822 rows × 7 columns</p>
# </div>

# %%
#only keep mono-labeled data
df_mono_labeled = df_pd[df_pd["topic_type"].str.contains(",")==False]
df_mono_labeled
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[157]: </div>
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>start</th>
#       <th>end</th>
#       <th>topic_type</th>
#       <th>nps</th>
#       <th>comments</th>
#       <th>subscription</th>
#       <th>userId</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>2021-03-26 15:05:00</td>
#       <td>2021-03-26 15:09:00</td>
#       <td>2</td>
#       <td>5</td>
#       <td>Unreliable shipping</td>
#       <td>GB</td>
#       <td>u-h050dssk4l1jjw7</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>2021-03-26 23:49:00</td>
#       <td>2021-03-26 23:55:00</td>
#       <td>1</td>
#       <td>4</td>
#       <td>I wouldn't always recommend because I feel lik...</td>
#       <td>GB</td>
#       <td>u-h0512xdjmys21ik5</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>2021-03-26 11:45:00</td>
#       <td>2021-03-26 11:51:00</td>
#       <td>3</td>
#       <td>6</td>
#       <td>It's a great concept but I do feel like it can...</td>
#       <td>GB</td>
#       <td>u-h0516q8jpz5o1z9e</td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td>2021-02-26 14:54:00</td>
#       <td>2021-02-26 14:57:00</td>
#       <td>3</td>
#       <td>6</td>
#       <td>Love the bags, but the products can be repetitive</td>
#       <td>GB</td>
#       <td>u-h051m9he429a1sx2</td>
#     </tr>
#     <tr>
#       <th>6</th>
#       <td>2021-02-26 11:11:00</td>
#       <td>2021-02-26 11:14:00</td>
#       <td>2</td>
#       <td>3</td>
#       <td>The time to receive it in Canada</td>
#       <td>GB</td>
#       <td>u-h051q6k26coy5fg</td>
#     </tr>
#     <tr>
#       <th>...</th>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#     </tr>
#     <tr>
#       <th>10817</th>
#       <td>2021-05-27 15:04:00</td>
#       <td>2021-05-27 15:10:00</td>
#       <td>10</td>
#       <td>0</td>
#       <td>I don't like your products.</td>
#       <td>GBX</td>
#       <td>u-km448odifvrb6g4</td>
#     </tr>
#     <tr>
#       <th>10818</th>
#       <td>2021-05-27 15:04:00</td>
#       <td>2021-05-27 15:08:00</td>
#       <td>8</td>
#       <td>3</td>
#       <td>Too many bags, allow the option to go bagless!</td>
#       <td>GBX</td>
#       <td>u-kkpn5f2750jt15hf</td>
#     </tr>
#     <tr>
#       <th>10819</th>
#       <td>2021-05-27 15:03:00</td>
#       <td>2021-05-27 15:04:00</td>
#       <td>2</td>
#       <td>2</td>
#       <td>It has been over a month and I still haven't r...</td>
#       <td>GBX</td>
#       <td>u-kndy2lj1fc31nv5</td>
#     </tr>
#     <tr>
#       <th>10820</th>
#       <td>2021-05-27 15:03:00</td>
#       <td>2021-05-27 15:15:00</td>
#       <td>9</td>
#       <td>0</td>
#       <td>Because it wasn't worth it to me. Spending tha...</td>
#       <td>GBX</td>
#       <td>u-ist8xiki612uefx</td>
#     </tr>
#     <tr>
#       <th>10821</th>
#       <td>2021-05-27 15:03:00</td>
#       <td>2021-05-27 15:08:00</td>
#       <td>2</td>
#       <td>4</td>
#       <td>Only received one month so far</td>
#       <td>GBX</td>
#       <td>u-ko4adrzogvyccyf</td>
#     </tr>
#   </tbody>
# </table>
# <p>9139 rows × 7 columns</p>
# </div>

# %%
#Replace weird syntax
'''
ex: ‚Äô --> '
ex: ‚Äú --> " (opening quote)
ex: ‚Äù --> " (ending quote)
'''
weird_syntax = {"‚Äô": '\'', 
                "‚Äú": '\'', 
                "‚Äù": '\'',
                "‚Äò": '\'',
                "‚Äö√Ñ√¥": '\'',
                "‚Äö√Ñ√∫": '\'',
                "‚Äö√Ñ√π": '\'',
                "‚Äî": ' ',
                "‚Ä¶": ' ',
                "Ô£ø√º¬ß‚àëÔ£ø√º√®√¶": ' ',
                "‚Å∞": ' ',
                "‚ù§": ' ',
                "‚óç‚Ä¢·¥ó‚Ä¢‚óç": ' ',
                "ü§∑‚Äç‚ôÄÔ∏è": ' '
               }

for index, item in df_mono_labeled['comments'].items():
  for key in weird_syntax:
    df_mono_labeled['comments'][index] = df_mono_labeled['comments'][index].replace(key, weird_syntax[key])
  
df_mono_labeled.display()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">&lt;command-4674445&gt;:25: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_mono_labeled[&#39;comments&#39;][index] = df_mono_labeled[&#39;comments&#39;][index].replace(key, weird_syntax[key])
# /databricks/python/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3418: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   exec(code_obj, self.user_global_ns, self.user_ns)
# </div>
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>start</th><th>end</th><th>topic_type</th><th>nps</th><th>comments</th><th>subscription</th><th>userId</th></tr></thead><tbody><tr><td>2021-03-26 15:05:00</td><td>2021-03-26 15:09:00</td><td>2</td><td>5</td><td>Unreliable shipping</td><td>GB</td><td>u-h050dssk4l1jjw7</td></tr><tr><td>2021-03-26 23:49:00</td><td>2021-03-26 23:55:00</td><td>1</td><td>4</td><td>I wouldn't always recommend because I feel like my bags have been SO hit or miss lately</td><td>GB</td><td>u-h0512xdjmys21ik5</td></tr><tr><td>2021-03-26 11:45:00</td><td>2021-03-26 11:51:00</td><td>3</td><td>6</td><td>It's a great concept but I do feel like it can get quiet repetitive.</td><td>GB</td><td>u-h0516q8jpz5o1z9e</td></tr><tr><td>2021-02-26 14:54:00</td><td>2021-02-26 14:57:00</td><td>3</td><td>6</td><td>Love the bags, but the products can be repetitive</td><td>GB</td><td>u-h051m9he429a1sx2</td></tr><tr><td>2021-02-26 11:11:00</td><td>2021-02-26 11:14:00</td><td>2</td><td>3</td><td>The time to receive it in Canada</td><td>GB</td><td>u-h051q6k26coy5fg</td></tr><tr><td>2021-02-26 11:13:00</td><td>2021-02-26 11:46:00</td><td>3</td><td>6</td><td>seems too many duplicates</td><td>GB</td><td>u-h051xhknju0i14jt</td></tr><tr><td>2021-03-26 11:45:00</td><td>2021-03-26 11:49:00</td><td>2</td><td>6</td><td>i enjoyed it in the past and just reopened my account but it's been13 days and I still don't have my shipment</td><td>GB</td><td>u-h0dxjpwaodmcxp</td></tr><tr><td>2021-02-26 11:33:00</td><td>2021-02-26 11:40:00</td><td>1</td><td>5</td><td>My preferred colors are not generally provided. I do give away quite a few products.</td><td>GB</td><td>u-h1ammj222zqc2ch</td></tr><tr><td>2021-02-26 11:07:00</td><td>2021-02-26 11:22:00</td><td>5</td><td>5</td><td>Too many mini products. I live in Canada and I would prefer to pay extra for full-size products but those options aren't available to me</td><td>GB</td><td>u-h5e6gdlfecfbadk</td></tr><tr><td>2021-02-26 16:36:00</td><td>2021-02-26 16:41:00</td><td>3</td><td>5</td><td>It's good for the price but it's not always exciting because they repeat products or do too many of the same type in one bag</td><td>GB</td><td>u-h7kycw0w7fqd17x</td></tr><tr><td>2021-02-26 13:50:00</td><td>2021-02-26 14:04:00</td><td>11</td><td>6</td><td>There can be some good products</td><td>GB</td><td>u-h7l9mjgk7dhu71f</td></tr><tr><td>2021-03-26 11:56:00</td><td>2021-03-26 12:01:00</td><td>3</td><td>6</td><td>Need a little more variety.</td><td>GB</td><td>u-h93ltzheptvh48o</td></tr><tr><td>2021-03-26 11:20:00</td><td>2021-03-26 11:54:00</td><td>3</td><td>6</td><td>I feel like I get the same colors all the time. I like the products and do get a different color every once in a while, but wouldn't recommend based on the lack of variety.</td><td>GB</td><td>u-ha4jvgqqka9r2mv</td></tr><tr><td>2021-02-26 17:41:00</td><td>2021-02-26 21:45:00</td><td>8</td><td>2</td><td>Gone downhill</td><td>GB</td><td>u-hbq5kjbu7hnb1xsv</td></tr><tr><td>2021-02-26 20:39:00</td><td>2021-02-26 20:45:00</td><td>10</td><td>0</td><td>The quality of the products has declined over the last six months. I'm really not enjoying the bags at all anymore.</td><td>GB</td><td>u-hc3k81up99blj1g</td></tr><tr><td>2021-02-26 12:30:00</td><td>2021-02-26 12:34:00</td><td>8</td><td>5</td><td>Need more selections</td><td>GB</td><td>u-hca53eozqzhx615</td></tr><tr><td>2021-03-27 18:34:00</td><td>2021-03-27 18:42:00</td><td>11</td><td>5</td><td>Because it can be kinda fun but I don't think it works for all people. I'd encourage people to try it out if they already appealed to them, but I wouldn't recommend it to just anyone.</td><td>GB</td><td>u-hcgj3r619cqpocq</td></tr><tr><td>2021-02-26 12:33:00</td><td>2021-02-26 12:43:00</td><td>8</td><td>5</td><td>I had subscription years ago and got rid of it. I've just re-subscribed and just got my bag today. So I have to give it time to see if the prod ...

# %%
#Filter out random comments
random = ["na", "na ", "no", "no ", "Na", "Na ", "No", "No ", "NA", "NA ", "NO", "NO ", "n/a", "n/a ", "N/A", "N/A ", ".", ". ", "?", "? ", ",", ", ", "!", "! ", "..", ".. ", "...", "... ", "....", ".... ", ".....", "..... ", " ", "  ", "   ", "    ", "     "]

df_mono_labeled = df_mono_labeled[~df_mono_labeled['comments'].isin(random)]
df_mono_labeled
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[159]: </div>
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>start</th>
#       <th>end</th>
#       <th>topic_type</th>
#       <th>nps</th>
#       <th>comments</th>
#       <th>subscription</th>
#       <th>userId</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>2021-03-26 15:05:00</td>
#       <td>2021-03-26 15:09:00</td>
#       <td>2</td>
#       <td>5</td>
#       <td>Unreliable shipping</td>
#       <td>GB</td>
#       <td>u-h050dssk4l1jjw7</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>2021-03-26 23:49:00</td>
#       <td>2021-03-26 23:55:00</td>
#       <td>1</td>
#       <td>4</td>
#       <td>I wouldn't always recommend because I feel lik...</td>
#       <td>GB</td>
#       <td>u-h0512xdjmys21ik5</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>2021-03-26 11:45:00</td>
#       <td>2021-03-26 11:51:00</td>
#       <td>3</td>
#       <td>6</td>
#       <td>It's a great concept but I do feel like it can...</td>
#       <td>GB</td>
#       <td>u-h0516q8jpz5o1z9e</td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td>2021-02-26 14:54:00</td>
#       <td>2021-02-26 14:57:00</td>
#       <td>3</td>
#       <td>6</td>
#       <td>Love the bags, but the products can be repetitive</td>
#       <td>GB</td>
#       <td>u-h051m9he429a1sx2</td>
#     </tr>
#     <tr>
#       <th>6</th>
#       <td>2021-02-26 11:11:00</td>
#       <td>2021-02-26 11:14:00</td>
#       <td>2</td>
#       <td>3</td>
#       <td>The time to receive it in Canada</td>
#       <td>GB</td>
#       <td>u-h051q6k26coy5fg</td>
#     </tr>
#     <tr>
#       <th>...</th>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#     </tr>
#     <tr>
#       <th>10817</th>
#       <td>2021-05-27 15:04:00</td>
#       <td>2021-05-27 15:10:00</td>
#       <td>10</td>
#       <td>0</td>
#       <td>I don't like your products.</td>
#       <td>GBX</td>
#       <td>u-km448odifvrb6g4</td>
#     </tr>
#     <tr>
#       <th>10818</th>
#       <td>2021-05-27 15:04:00</td>
#       <td>2021-05-27 15:08:00</td>
#       <td>8</td>
#       <td>3</td>
#       <td>Too many bags, allow the option to go bagless!</td>
#       <td>GBX</td>
#       <td>u-kkpn5f2750jt15hf</td>
#     </tr>
#     <tr>
#       <th>10819</th>
#       <td>2021-05-27 15:03:00</td>
#       <td>2021-05-27 15:04:00</td>
#       <td>2</td>
#       <td>2</td>
#       <td>It has been over a month and I still haven't r...</td>
#       <td>GBX</td>
#       <td>u-kndy2lj1fc31nv5</td>
#     </tr>
#     <tr>
#       <th>10820</th>
#       <td>2021-05-27 15:03:00</td>
#       <td>2021-05-27 15:15:00</td>
#       <td>9</td>
#       <td>0</td>
#       <td>Because it wasn't worth it to me. Spending tha...</td>
#       <td>GBX</td>
#       <td>u-ist8xiki612uefx</td>
#     </tr>
#     <tr>
#       <th>10821</th>
#       <td>2021-05-27 15:03:00</td>
#       <td>2021-05-27 15:08:00</td>
#       <td>2</td>
#       <td>4</td>
#       <td>Only received one month so far</td>
#       <td>GBX</td>
#       <td>u-ko4adrzogvyccyf</td>
#     </tr>
#   </tbody>
# </table>
# <p>9102 rows × 7 columns</p>
# </div>

# %%
#Shift date and add month column

df_mono_labeled['date'] = pd.to_datetime(df_mono_labeled['end'], format='%Y-%m-%d')
df_mono_labeled['date_shifted'] = df_mono_labeled['date'] + pd.TimedeltaIndex( [-6]*len(df_mono_labeled.index), unit='d') #shift back 6 days
df_mono_labeled['month'] = pd.DatetimeIndex(df_mono_labeled['date_shifted']).month
df_mono_labeled['month'] = df_mono_labeled['month'].apply(lambda x: calendar.month_abbr[x])
df_mono_labeled = df_mono_labeled.drop(['date', 'date_shifted'], axis=1)
df_mono_labeled
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">&lt;command-4659661&gt;:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_mono_labeled[&#39;date&#39;] = pd.to_datetime(df_mono_labeled[&#39;end&#39;], format=&#39;%Y-%m-%d&#39;)
# &lt;command-4659661&gt;:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_mono_labeled[&#39;date_shifted&#39;] = df_mono_labeled[&#39;date&#39;] + pd.TimedeltaIndex( [-6]*len(df_mono_labeled.index), unit=&#39;d&#39;) #shift back 6 days
# &lt;command-4659661&gt;:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_mono_labeled[&#39;month&#39;] = pd.DatetimeIndex(df_mono_labeled[&#39;date_shifted&#39;]).month
# &lt;command-4659661&gt;:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_mono_labeled[&#39;month&#39;] = df_mono_labeled[&#39;month&#39;].apply(lambda x: calendar.month_abbr[x])
# Out[160]: </div>
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>start</th>
#       <th>end</th>
#       <th>topic_type</th>
#       <th>nps</th>
#       <th>comments</th>
#       <th>subscription</th>
#       <th>userId</th>
#       <th>month</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>2021-03-26 15:05:00</td>
#       <td>2021-03-26 15:09:00</td>
#       <td>2</td>
#       <td>5</td>
#       <td>Unreliable shipping</td>
#       <td>GB</td>
#       <td>u-h050dssk4l1jjw7</td>
#       <td>Mar</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>2021-03-26 23:49:00</td>
#       <td>2021-03-26 23:55:00</td>
#       <td>1</td>
#       <td>4</td>
#       <td>I wouldn't always recommend because I feel lik...</td>
#       <td>GB</td>
#       <td>u-h0512xdjmys21ik5</td>
#       <td>Mar</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>2021-03-26 11:45:00</td>
#       <td>2021-03-26 11:51:00</td>
#       <td>3</td>
#       <td>6</td>
#       <td>It's a great concept but I do feel like it can...</td>
#       <td>GB</td>
#       <td>u-h0516q8jpz5o1z9e</td>
#       <td>Mar</td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td>2021-02-26 14:54:00</td>
#       <td>2021-02-26 14:57:00</td>
#       <td>3</td>
#       <td>6</td>
#       <td>Love the bags, but the products can be repetitive</td>
#       <td>GB</td>
#       <td>u-h051m9he429a1sx2</td>
#       <td>Feb</td>
#     </tr>
#     <tr>
#       <th>6</th>
#       <td>2021-02-26 11:11:00</td>
#       <td>2021-02-26 11:14:00</td>
#       <td>2</td>
#       <td>3</td>
#       <td>The time to receive it in Canada</td>
#       <td>GB</td>
#       <td>u-h051q6k26coy5fg</td>
#       <td>Feb</td>
#     </tr>
#     <tr>
#       <th>...</th>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#     </tr>
#     <tr>
#       <th>10817</th>
#       <td>2021-05-27 15:04:00</td>
#       <td>2021-05-27 15:10:00</td>
#       <td>10</td>
#       <td>0</td>
#       <td>I don't like your products.</td>
#       <td>GBX</td>
#       <td>u-km448odifvrb6g4</td>
#       <td>May</td>
#     </tr>
#     <tr>
#       <th>10818</th>
#       <td>2021-05-27 15:04:00</td>
#       <td>2021-05-27 15:08:00</td>
#       <td>8</td>
#       <td>3</td>
#       <td>Too many bags, allow the option to go bagless!</td>
#       <td>GBX</td>
#       <td>u-kkpn5f2750jt15hf</td>
#       <td>May</td>
#     </tr>
#     <tr>
#       <th>10819</th>
#       <td>2021-05-27 15:03:00</td>
#       <td>2021-05-27 15:04:00</td>
#       <td>2</td>
#       <td>2</td>
#       <td>It has been over a month and I still haven't r...</td>
#       <td>GBX</td>
#       <td>u-kndy2lj1fc31nv5</td>
#       <td>May</td>
#     </tr>
#     <tr>
#       <th>10820</th>
#       <td>2021-05-27 15:03:00</td>
#       <td>2021-05-27 15:15:00</td>
#       <td>9</td>
#       <td>0</td>
#       <td>Because it wasn't worth it to me. Spending tha...</td>
#       <td>GBX</td>
#       <td>u-ist8xiki612uefx</td>
#       <td>May</td>
#     </tr>
#     <tr>
#       <th>10821</th>
#       <td>2021-05-27 15:03:00</td>
#       <td>2021-05-27 15:08:00</td>
#       <td>2</td>
#       <td>4</td>
#       <td>Only received one month so far</td>
#       <td>GBX</td>
#       <td>u-ko4adrzogvyccyf</td>
#       <td>May</td>
#     </tr>
#   </tbody>
# </table>
# <p>9102 rows × 8 columns</p>
# </div>

# %%
#Add NPS type column (detractors, passives, and promoters)
df_mono_labeled['nps'] = df_mono_labeled['nps'].astype(int)
df_mono_labeled["nps_type"] = df_mono_labeled["nps"].apply(lambda x : 'detractor' if x <=6 else 'passive' if x <=8 else 'promotor')
df_mono_labeled['nps'] = df_mono_labeled['nps'].astype(str)

df_mono_labeled
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out
#       <td>9</td>
#       <td>0</td>
#       <td>Because it wasn't worth it to me. Spending tha...</td>
#       <td>GBX</td>
#       <td>u-ist8xiki612uefx</td>
#       <td>May</td>
#       <td>detractor</td>
#     </tr>
#     <tr>
#       <th>10821</th>
#       <td>2021-05-27 15:03:00</td>
#       <td>2021-05-27 15:08:00</td>
#       <td>2</td>
#       <td>4</td>
#       <td>Only received one month so far</td>
#       <td>GBX</td>
#       <td>u-ko4adrzogvyccyf</td>
#       <td>May</td>
#       <td>detractor</td>
#     </tr>
#   </tbody>
# </table>
# <p>9102 rows × 9 columns</p>
# </div>

# %%
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %% [markdown]
# ###Flair

# %%
#Get comment score and type (POSITIVE or NEGATIVE) of each comment

def comment_score(row): 
  sentence = str(row['comments'])
  s = flair.data.Sentence(sentence)
  flair_sentiment.predict(s)
  total_sentiment = s.labels
  s = total_sentiment[0].to_dict()
  return s['value'], s['confidence']

df_mono_labeled['comment_type'], df_mono_labeled['comment_score'] = zip(*df_mono_labeled.apply(comment_score, axis=1))
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
df_mono_labeled['comment_score'] = df_mono_labeled['comment_score'] * 1000
df_mono_labeled["comment_score"] = df_mono_labeled["comment_score"].astype(int)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
#Filter out positive comments

df_neg = df_mono_labeled[(df_mono_labeled["comment_type"]=='NEGATIVE')].sort_values(by = 'comment_score')
df_neg.display()
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>start</th><th>end</th><th>topic_type</th><th>nps</th><th>comments</th><th>subscription</th><th>userId</th><th>month</th><th>nps_type</th><th>comment_type</th><th>comment_score</th></tr></thead><tbody><tr><td>2021-06-28 12:45:40</td><td>2021-06-28 12:50:04</td><td>8</td><td>5</td><td>Only recommend if they ask</td><td>GB+</td><td>u-iriixfnrm0r6hs6</td><td>Jun</td><td>detractor</td><td>NEGATIVE</td><td>500</td></tr><tr><td>2021-03-26 11:13:00</td><td>2021-03-26 11:17:00</td><td>11</td><td>5</td><td>Cheaper prices and discount sales</td><td>GB</td><td>u-iqe89p6v73onzi9</td><td>Mar</td><td>detractor</td><td>NEGATIVE</td><td>501</td></tr><tr><td>2021-06-28 13:46:00</td><td>2021-06-28 13:53:00</td><td>1</td><td>2</td><td>Didn't have enough products that I like.</td><td>GB</td><td>u-kp1jb61pcqad1qt4</td><td>Jun</td><td>detractor</td><td>NEGATIVE</td><td>502</td></tr><tr><td>2021-03-26 16:46:40</td><td>2021-03-26 16:51:01</td><td>8</td><td>3</td><td>Because you shove it in our face to</td><td>GB+</td><td>u-k4rir4mi1bpak6a</td><td>Mar</td><td>detractor</td><td>NEGATIVE</td><td>502</td></tr><tr><td>2021-05-27 15:13:00</td><td>2021-05-27 15:14:00</td><td>1</td><td>5</td><td>sometimes the products are on point, sometimes they are not</td><td>GB</td><td>u-jr5cvpznoszkkox</td><td>May</td><td>detractor</td><td>NEGATIVE</td><td>502</td></tr><tr><td>2021-06-28 11:05:35</td><td>2021-06-28 11:09:46</td><td>8</td><td>6</td><td>I don’t know many people that wear makeup</td><td>GB+</td><td>u-k2fg5n6omd1m1lu</td><td>Jun</td><td>detract

# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
import pandas as pd
from sklearn.preprocessing import LabelEncoder

def read_comments(df, test_size=0.2):
    labelencoder = LabelEncoder()
    df['topic_type_label'] = labelencoder.fit_transform(df['topic_type']) #transforms topic type from strs to ints
    documents = df.comments.tolist()
    labels = df.topic_type_label.tolist()
    return train_test_split(documents, labels, test_size=test_size, stratify=labels), labelencoder.classes_ 
      
(train_texts, valid_texts, train_labels, valid_labels), target_names = read_comments(df_neg, test_size)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
print("target names: ", target_names)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>

# %%
# tokenize the dataset, truncate when passed `max_length`, 
# and pad with 0's when less than `max_length`
# always tokenize after splitting
train_encodings = tokenizer(train_texts, truncation=True, padding=True, max_length=200)
valid_encodings = tokenizer(valid_texts, truncation=True, padding=True, max_length=200)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
class comment_dataset(torch.utils.data.Dataset):
    def __init__(self, encodings, labels):
        self.encodings = encodings
        self.labels = labels

    def __getitem__(self, idx):
        item = {k: torch.tensor(v[idx]) for k, v in self.encodings.items()}
        item["labels"] = torch.tensor([self.labels[idx]])
        return item

    def __len__(self):
        return len(self.labels)

# convert our tokenized data into a torch Dataset
train_dataset = comment_dataset(train_encodings, train_labels)
valid_dataset = comment_dataset(valid_encodings, valid_labels)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
# load the model and pass to CUDA
model = BertForSequenceClassification.from_pretrained(model_name, num_labels=len(target_names))#.to("cuda")
#from transformers import AutoModelForSequenceClassification
#model = AutoModelForSequenceClassification.from_pretrained("bert-base-cased", num_labels=len(set(target_names)))
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# Downloading: 100%|██████████| 570/570 [00:00&lt;00:00, 338kB/s]
# Downloading: 100%|██████████| 440M/440M [00:05&lt;00:00, 81.9MB/s]
# Some weights of the model checkpoint at bert-base-uncased were not used when initializing BertForSequenceClassification: [&#39;cls.predictions.transform.dense.bias&#39;, &#39;cls.seq_relationship.bias&#39;, &#39;cls.predictions.transform.LayerNorm.weight&#39;, &#39;cls.predictions.decoder.weight&#39;, &#39;cls.predictions.transform.dense.weight&#39;, &#39;cls.seq_relationship.weight&#39;, &#39;cls.predictions.transform.LayerNorm.bias&#39;, &#39;cls.predictions.bias&#39;]
# - This IS expected if you are initializing BertForSequenceClassification from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing BertForSequenceClassification from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Some weights of BertForSequenceClassification were not initialized from the model checkpoint at bert-base-uncased and are newly initialized: [&#39;classifier.bias&#39;, &#39;classifier.weight&#39;]
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# </div>

# %%
from sklearn.metrics import accuracy_score
from sklearn.metrics import f1_score

def compute_metrics(pred):
    labels = pred.label_ids
    preds = pred.predictions.argmax(-1)
    acc = accuracy_score(labels, preds)
    f1_scores = f1_score(labels, preds, average='weighted')
    return {'accuracy': acc, 'f1_score': f1_scores,}
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
#Read data from widget

#dbutils.widgets.removeAll()
#dbutils.widgets.remove("Base Path")
NUM_EPOCHS = "c) Num of Train Epochs"
dbutils.widgets.dropdown(NUM_EPOCHS, "15", ["5", "10", "15", "20"])
num_epochs = int(dbutils.widgets.get(NUM_EPOCHS))
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
training_args = TrainingArguments(
    output_dir='./results',          # output directory
    num_train_epochs=num_epochs,     # total number of training epochs
    per_device_train_batch_size=32,  # batch size per device during training
    per_device_eval_batch_size=32,   # batch size for evaluation
    warmup_steps=10,                # number of warmup steps for learning rate scheduler
    weight_decay=0.01,               # strength of weight decay
    logging_dir='./logs',            # directory for storing logs
    load_best_model_at_end=True,     # load the best model when finished training (default metric is loss)
    # but you can specify `metric_for_best_model` argument to change to accuracy or other metric
    logging_steps=100,               # log & save weights each logging_steps
    evaluation_strategy="steps",     # evaluate each `logging_steps`
)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
trainer = Trainer(
    model=model,                         # the instantiated Transformers model to be trained
    args=training_args,                  # training arguments, defined above
    train_dataset=train_dataset,         # training dataset
    eval_dataset=valid_dataset,          # evaluation dataset
    compute_metrics=compute_metrics,     # the callback that computes metrics of interest
)

# %%
# train the model
trainer.train()

# %%
#clear prev model storage
#! rm -rf results/checkpoint-*
#! df -h /databricks/driver

# evaluate the current model after training
trainer.evaluate()

# %%
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>

# %% [markdown]
# ###Save Model

# %%
# saving the fine tuned model & tokenizer - https://huggingface.co/transformers/main_classes/model.html

model_path = "sentiment-topic-bert-base-uncased"
model.save_pretrained(model_path)
tokenizer.save_pretrained(model_path)

# %%
SAVE_PATH = "d) Save Path"
dbutils.widgets.text(SAVE_PATH, "dbfs:/mnt/ipsy-databricks-mlp/research/ethan/monolabeled-model-full-w-others-copy")
save_path = dbutils.widgets.get(SAVE_PATH)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
#save to amazon s3
dbutils.fs.mv("file:/databricks/driver/sentiment-topic-bert-base-uncased", save_path, recurse=True)

# %%
#load saved model
dbutils.fs.cp(save_path, "file:/databricks/driver/sentiment-topic-bert-base-uncased", recurse=True)
tokenizer_2 = BertTokenizerFast.from_pretrained(model_path)
model_2 = BertForSequenceClassification.from_pretrained(model_path, num_labels=len(target_names))#.to("cuda")

# %% [markdown]
# ###Evaluating Model

# %%
df_used = df_neg[:]
df_used

# %%
def get_prediction_clean(text):
    # prepare our text into tokenized sequence
    inputs = tokenizer_2(text, padding=True, truncation=True, max_length=max_length, return_tensors="pt")
    # perform inference to our model
    outputs = model_2(**inputs)
    # get output probabilities by doing softmax
    probs = outputs[0].softmax(1)
    # executing argmax function to get the candidate label
    return target_names[probs.argmax()]

# %%
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix

def accuracy(y: list, pred: list):
    # accuracy: (tp + tn) / (p + n)
    from sklearn.metrics import accuracy_score
    accuracy = accuracy_score(y, pred)    
    return accuracy

def cm(y: list, pred: list):
    from sklearn.metrics import confusion_matrix
    return confusion_matrix(y, pred)  
  
def confusion_matrix_plot(y, pred, normalize=False):
    plot_confusion_matrix(y, pred, classes=target_names, normalize=normalize, title='Confusion matrix')

def plot_confusion_matrix(y_true, y_pred, classes, normalize=False, title=None, cmap=plt.cm.Blues):
    """
    This function prints and plots the confusion matrix.
    Normalization can be applied by setting `normalize=True`.
    """
    from sklearn.utils.multiclass import unique_labels
    from sklearn.metrics import confusion_matrix

    # Compute confusion matrix
    cm = confusion_matrix(y_true, y_pred)
    # Only use the labels that appear in the data
    if normalize:
        cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]

    fig, ax = plt.subplots()
    im = ax.imshow(cm, interpolation='nearest', cmap=cmap)
    ax.figure.colorbar(im, ax=ax)
    # We want to show all ticks...
    ax.set(xticks=np.arange(cm.shape[1]),
        yticks=np.arange(cm.shape[0]),
        # ... and label them with the respective list entries
        xticklabels=classes, yticklabels=classes,
        title=title,
        ylabel='True label',
        xlabel='Predicted label')

    # Rotate the tick labels and set their alignment.
    plt.setp(ax.get_xticklabels(), rotation=45, ha="right", rotation_mode="anchor")

    # Loop over data dimensions and create text annotations.
    fmt = '.2f' if normalize else 'd'
    thresh = cm.max() / 2.
    for i in range(cm.shape[0]):
        for j in range(cm.shape[1]):
            ax.text(j, i, format(cm[i, j], fmt),
                    ha="center", va="center",
                    color="white" if cm[i, j] > thresh else "black")
    fig.tight_layout()
    return ax
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>

# %% [markdown]
# ####All Data

# %%
df_used['predicted_label'] = df_used['comments'].apply(get_prediction_clean)
actual_label = df_used['topic_type']
pred_label = df_used['predicted_label']
df_used

# %%
confusion_matrix_plot(actual_label, pred_label)

# %%
confusion_matrix_plot(actual_label, pred_label, normalize=True)

# %%
from sklearn.metrics import classification_report
# accuracy = (tp + tn) / (tp + tn + fp + fn)
# precision = tp / (tp + fp)   tp out of all labeled p
# recall = tp / (tp + fn)      tp out of all actually p
# f1 = weighted avg of precision and recall
print('accuracy: ', accuracy(actual_label, pred_label))
print()
print(classification_report(actual_label, pred_label))

# %% [markdown]
# ####Testing Data

# %%
testing_data_df = pd.DataFrame(target_names[valid_labels], columns = ['topic_type'])
testing_data_df['comments'] = valid_texts
testing_data_df

# %%
testing_data_df['predicted_label'] = testing_data_df['comments'].apply(get_prediction_clean)
testing_data_actual_label = testing_data_df['topic_type']
testing_data_predicted_label = testing_data_df['predicted_label']
testing_data_df

# %%
confusion_matrix_plot(testing_data_actual_label, testing_data_predicted_label)

# %%
confusion_matrix_plot(testing_data_actual_label, testing_data_predicted_label, normalize=True)

# %%
# accuracy = (tp + tn) / (tp + tn + fp + fn)
# precision = tp / (tp + fp)   tp out of all labeled p
# recall = tp / (tp + fn)      tp out of all actually p
# f1 = weighted avg of precision and recall
print('accuracy: ', accuracy(testing_data_actual_label, testing_data_predicted_label))
print()
print(classification_report(testing_data_actual_label, testing_data_predicted_label))
